# %% [markdown]
# <a href="https://colab.research.google.com/github/mrerror313coder/GoogleColab_AI_Work/blob/main/Python_Competative.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sum of n Natural numbers

num = int(input("Enter a number: "))
total = 0
for i in range(1,num+1):
  total = total+i

print(total)
# Out:
# Enter a number: 5
# 15
